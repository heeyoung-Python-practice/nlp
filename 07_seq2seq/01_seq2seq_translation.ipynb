# %% [markdown]
# # Seq2Seq (Sequence-to-Sequence)
#
# ### Embedding Vector
#
# 1. 영어 Glove 임베딩 (사전 학습) 사용 / 6B tokens, 400K vocab, uncased, 100d
# 2. 한국어 임베딩 (초기 훈련)

# %%
# !gdown 1qk-14tgVHPXT5jfRUE4Ua2ji4EXwS022
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1qk-14tgVHPXT5jfRUE4Ua2ji4EXwS022
# From (redirected): https://drive.google.com/uc?id=1qk-14tgVHPXT5jfRUE4Ua2ji4EXwS022&confirm=t&uuid=2731cc67-6f00-484f-972f-8f5d5e4ac61a
# To: c:\Users\Playdata\nlp\07_seq2seq\glove.6B.100d.txt
#
#   0%|          | 0.00/347M [00:00<?, ?B/s]
#   0%|          | 524k/347M [00:00<05:10, 1.12MB/s]
#   1%|          | 2.10M/347M [00:00<01:17, 4.46MB/s]
#   2%|▏         | 6.29M/347M [00:00<00:33, 10.2MB/s]
#   3%|▎         | 10.5M/347M [00:01<00:25, 13.3MB/s]
#   5%|▌         | 18.9M/347M [00:01<00:15, 21.8MB/s]
#   6%|▌         | 21.5M/347M [00:01<00:15, 21.2MB/s]
#   8%|▊         | 26.7M/347M [00:01<00:11, 26.8MB/s]
#   9%|▉         | 32.5M/347M [00:01<00:09, 33.4MB/s]
#  11%|█         | 38.3M/347M [00:01<00:07, 39.1MB/s]
#  12%|█▏        | 43.0M/347M [00:01<00:07, 40.8MB/s]
#  14%|█▎        | 47.7M/347M [00:01<00:08, 34.6MB/s]
#  15%|█▌        | 52.4M/347M [00:02<00:08, 36.3MB/s]
#  16%|█▋        | 56.6M/347M [00:02<00:07, 37.4MB/s]
#  18%|█▊        | 62.9M/347M [00:02<00:06, 43.6MB/s]
#  19%|█▉        | 67.6M/347M [00:02<00:06, 43.9MB/s]
#  21%|██        | 72.4M/347M [00:02<00:06, 44.8MB/s]
#  22%|██▏       | 77.1M/347M [00:02<00:06, 40.3MB/s]
#  24%|██▍       | 84.4M/347M [00:02<00:05, 48.6MB/s]
#  26%|██▌       | 89.7M/347M [00:02<00:05, 47.8MB/s]
#  27%|██▋       | 95.4M/347M [00:03<00:05, 48.6MB/s]
#  29%|██▉       | 101M/347M [00:03<00:05, 47.8MB/s]
#  31%|███       | 106M/347M [00:03<00:05, 45.9MB/s]
#  32%|███▏      | 111M/347M [00:03<00:05, 44.4MB/s]
#  33%|███▎      | 115M/347M [00:03<00:05, 45.0MB/s]
#  35%|███▍      | 121M/347M [00:03<00:04, 46.7MB/s]
#  36%|███▌      | 126M/347M [00:03<00:04, 47.9MB/s]
#  38%|███▊      | 131M/347M [00:03<00:04, 47.8MB/s]
#  39%|███▉      | 136M/347M [00:03<00:04, 48.1MB/s]
#  41%|████      | 142M/347M [00:04<00:04, 46.0MB/s]
#  42%|████▏     | 146M/347M [00:04<00:04, 40.2MB/s]
#  43%|████▎     | 150M/347M [00:04<00:04, 40.4MB/s]
#  45%|████▍     | 155M/347M [00:04<00:04, 41.8MB/s]
#  46%|████▌     | 160M/347M [00:04<00:04, 41.8MB/s]
#  48%|████▊     | 165M/347M [00:04<00:04, 41.7MB/s]
#  49%|████▉     | 170M/347M [00:04<00:04, 40.8MB/s]
#  50%|█████     | 175M/347M [00:04<00:04, 41.3MB/s]
#  52%|█████▏    | 180M/347M [00:04<00:03, 44.3MB/s]
#  53%|█████▎    | 186M/347M [00:05<00:03, 47.5MB/s]
#  55%|█████▌    | 191M/347M [00:05<00:03, 50.0MB/s]
#  57%|█████▋    | 197M/347M [00:05<00:02, 50.8MB/s]
#  59%|█████▊    | 203M/347M [00:05<00:02, 54.2MB/s]
#  60%|██████    | 209M/347M [00:05<00:02, 55.1MB/s]
#  62%|██████▏   | 215M/347M [00:05<00:02, 44.6MB/s]
#  63%|██████▎   | 220M/347M [00:05<00:03, 37.5MB/s]
#  65%|██████▌   | 226M/347M [00:05<00:02, 42.9MB/s]
#  67%|██████▋   | 233M/347M [00:06<00:02, 48.6MB/s]
#  69%|██████▉   | 241M/347M [00:06<00:01, 53.9MB/s]
#  71%|███████▏  | 247M/347M [00:06<00:01, 56.8MB/s]
#  73%|███████▎  | 254M/347M [00:06<00:01, 57.3MB/s]
#  75%|███████▍  | 260M/347M [00:06<00:01, 58.0MB/s]
#  77%|███████▋  | 267M/347M [00:06<00:01, 60.6MB/s]
#  79%|███████▊  | 273M/347M [00:06<00:01, 60.7MB/s]
#  81%|████████  | 279M/347M [00:06<00:01, 60.2MB/s]
#  82%|████████▏ | 286M/347M [00:06<00:01, 59.4MB/s]
#  84%|████████▍ | 293M/347M [00:06<00:00, 61.2MB/s]
#  86%|████████▌ | 299M/347M [00:07<00:00, 60.6MB/s]
#  88%|████████▊ | 305M/347M [00:07<00:00, 59.8MB/s]
#  90%|████████▉ | 311M/347M [00:07<00:00, 59.6MB/s]
#  92%|█████████▏| 318M/347M [00:07<00:00, 60.6MB/s]
#  93%|█████████▎| 325M/347M [00:07<00:00, 61.2MB/s]
#  95%|█████████▌| 331M/347M [00:07<00:00, 63.0MB/s]
#  97%|█████████▋| 338M/347M [00:07<00:00, 63.9MB/s]
#  99%|█████████▉| 345M/347M [00:07<00:00, 62.6MB/s]
# 100%|██████████| 347M/347M [00:07<00:00, 44.1MB/s]

# %% [markdown]
# ### 학습 데이터 준비
#
# http://www.manythings.org/anki/
#
# 1. Encoder 입력 데이터 eng
#     - encoder_input_eng 준비 `I love you`
# 2. Decoder 출력 데이터 kor
#     - 학습용 teacher-forcing 모델
#         - decoder_input_kor `<sos> 난 널 사랑해`
#         - docoder_output_kor `난 널 사랑해 <eos>`
#     - 추론용 모델

# %%
# !gdown 17-luLRrDsnP_yIzIchd3aCo_WMt4znPF -O eng_kor.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17-luLRrDsnP_yIzIchd3aCo_WMt4znPF
# To: c:\Users\Playdata\nlp\07_seq2seq\eng_kor.txt
#
#   0%|          | 0.00/864k [00:00<?, ?B/s]
#  61%|██████    | 524k/864k [00:00<00:00, 2.80MB/s]
# 100%|██████████| 864k/864k [00:00<00:00, 3.72MB/s]

# %%
eng_inputs = []    # 영어 원문 문장 리스트
kor_inputs = []    # 한국어 입력(디코더 입력) 리스트
kor_targets = []   # 한국어 타겟(정답) 리스트

with open('eng_kor.txt', 'r', encoding='utf-8') as f:
    for line in f:                        # 파일을 한 줄씩 순회
        eng, kor, _ = line.split('\t')    # "영어\t한국어\t(기타)" 형태로 분리

        kor_input = '<sos> ' + kor         # 디코더 입력 : 시작 토큰 추가
        kor_target = kor + ' <eos>'        # 디코더 타겟 : 종료 토큰 추가

        eng_inputs.append(eng)            # 영어 문장
        kor_inputs.append(kor_input)      # 한국어 입력 시퀀스
        kor_targets.append(kor_target)    # 한국어 타겟 시퀀스

len(eng_inputs), len(kor_inputs), len(kor_targets)
# Out:
# (5890, 5890, 5890)

# %%
print(eng_inputs[2500:2505])
print(kor_inputs[2500:2505])   # <sos> 토큰 포함
print(kor_targets[2500:2505])  # <eos> 토큰 포함
# Out:
# ['I speak French a little.', 'I take back what I said.', 'I tried to make friends.', 'I use this all the time.', 'I use this all the time.']
# ['<sos> 저는 프랑스어를 조금 합니다.', '<sos> 아까 한 말 취소야.', '<sos> 난 친구를 만드려고 했어.', '<sos> 나는 항상 이걸 쓴다.', '<sos> 매번 이걸 쓴다.']
# ['저는 프랑스어를 조금 합니다. <eos>', '아까 한 말 취소야. <eos>', '난 친구를 만드려고 했어. <eos>', '나는 항상 이걸 쓴다. <eos>', '매번 이걸 쓴다. <eos>']

# %% [markdown]
# ### 토큰화
# - 인코더(영어) : 영문 토크나이저
# - 디코더(한글) : 국문 토크나이저

# %%
VOCAB_SIZE = 10000  # 사용할 최대 어휘 수(상위 빈도 단어 기준)

# %% [markdown]
# ##### 영문 토큰화

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

eng_tokenizer = Tokenizer(num_words=VOCAB_SIZE, oov_token='<OOV>')  # 어휘 제한 + 미등록 단어를 <OOV>로 처리
eng_tokenizer.fit_on_texts(eng_inputs)                              # 영어 문장들로 단어 사전(word_index) 학습
eng_inputs_seq = eng_tokenizer.texts_to_sequences(eng_inputs)       # 영어 문장 -> 단어 ID 시퀀스로 변환

print(eng_inputs[2500:2505])
eng_inputs_seq[2500:2505]
# Out:
# ['I speak French a little.', 'I take back what I said.', 'I tried to make friends.', 'I use this all the time.', 'I use this all the time.']
# [[2, 130, 38, 8, 268],
#  [2, 111, 150, 27, 2, 82],
#  [2, 300, 4, 213, 202],
#  [2, 206, 12, 54, 6, 60],
#  [2, 206, 12, 54, 6, 60]]

# %%
for seq in eng_inputs_seq[2500:2505]:
    print([eng_tokenizer.index_word[idx] for idx in seq])  # 각 ID를 단어로 바꿔 토큰 리스트로 출력
# Out:
# ['i', 'speak', 'french', 'a', 'little']
# ['i', 'take', 'back', 'what', 'i', 'said']
# ['i', 'tried', 'to', 'make', 'friends']
# ['i', 'use', 'this', 'all', 'the', 'time']
# ['i', 'use', 'this', 'all', 'the', 'time']

# %%
# 실제 사용 어휘 수(설정한 VOCAB_SIZE와 사전 크기 중 작은 값)
eng_num_words = min(VOCAB_SIZE, len(eng_tokenizer.word_index))

# 영어 시퀀스들 중 가장 긴 문장의 토큰 길이
eng_max_len = max([len(seq) for seq in eng_inputs_seq])
print(eng_num_words, eng_max_len)
# Out:
# 3200 101

# %% [markdown]
# eng_max_len는 패딩 기준으로 쓸수있는 최대 시퀀스 길이가 저장되어 있다.

# %% [markdown]
# ##### 국문 토큰화

# %%
kor_tokenizer = Tokenizer(num_words=VOCAB_SIZE, oov_token='<OOV>', filters='')  # 필터 제거(특수토큰 <sos>/<eos> 유지)
kor_tokenizer.fit_on_texts(kor_inputs + kor_targets)  # 입력 + 타겟 전체로 단어 사전 학습

kor_inputs_seq = kor_tokenizer.texts_to_sequences(kor_inputs)     # 한국어 입력(<sos> 포함) -> ID 시퀀스
kor_targets_seq = kor_tokenizer.texts_to_sequences(kor_targets)   # 한국어 타겟(<eos> 포함) -> ID 시퀀스

print('<sos>' in kor_tokenizer.word_index, '<eos>' in kor_tokenizer.word_index)
# Out:
# True True

# %%
kor_tokenizer.index_word
# Out:
# {1: '<OOV>',
#  2: '<sos>',
#  3: '<eos>',
#  4: '톰은',
#  5: '나는',
#  6: '톰이',
#  7: '난',
#  8: '있어.',
#  9: '그',
#  10: '내가',
#  11: '수',
#  12: '이',
#  13: '내',
#  14: '그는',
#  15: '있다.',
#  16: '있어?',
#  17: '네가',
#  18: '것',
#  19: '우리는',
#  20: '것을',
#  21: '더',
#  22: '왜',
#  23: '할',
#  24: '너무',
#  25: '너',
#  26: '좀',
#  27: '안',
#  28: '네',
#  29: '정말',
#  30: '거야.',
#  31: '않아.',
#  32: '우리',
#  33: '한',
#  34: '없어.',
#  35: '같아.',
#  36: '그녀는',
#  37: '알고',
#  38: '걸',
#  39: '것이다.',
#  40: '프랑스어를',
#  41: '있는',
#  42: '없다.',
#  43: '줄',
#  44: '한다.',
#  45: '않는다.',
#  46: '이건',
#  47: '우린',
#  48: '잘',
#  49: '가장',
#  50: '해.',
#  51: '너는',
#  52: '톰을',
#  53: '하고',
#  54: '적',
#  55: '집에',
#  56: '사람은',
#  57: '했다.',
#  58: '그걸',
#  59: '아무도',
#  60: '여기',
#  61: '있을',
#  62: '건',
#  63: '날',
#  64: '넌',
#  65: '것은',
#  66: '그렇게',
#  67: '메리가',
#  68: '톰과',
#  69: '했어.',
#  70: '지금',
#  71: '않았다.',
#  72: '톰의',
#  73: '오늘',
#  74: '무슨',
#  75: '얼마나',
#  76: '그게',
#  77: '좋은',
#  78: '것이',
#  79: '아주',
#  80: '그의',
#  81: '나',
#  82: '그것을',
#  83: '하지',
#  84: '그건',
#  85: '어떻게',
#  86: '있었어.',
#  87: '적이',
#  88: '못',
#  89: '우리가',
#  90: '그가',
#  91: '누가',
#  92: '있었다.',
#  93: '거야?',
#  94: '아직도',
#  95: '모두',
#  96: '이게',
#  97: '내일',
#  98: '게',
#  99: '아직',
#  100: '좋아하는',
#  101: '주세요.',
#  102: '이거',
#  103: '다',
#  104: '때',
#  105: '당신은',
#  106: '톰한테',
#  107: '톰에게',
#  108: '그들은',
#  109: '메리는',
#  110: '아니야.',
#  111: '마.',
#  112: '계속',
#  113: '않다.',
#  114: '어떤',
#  115: '하는',
#  116: '널',
#  117: '모든',
#  118: '자기',
#  119: '사람들은',
#  120: '같이',
#  121: '많이',
#  122: '말했다.',
#  123: '그만',
#  124: '않았어.',
#  125: '말을',
#  126: '않을',
#  127: '책을',
#  128: '싶지',
#  129: '많은',
#  130: '대해',
#  131: '싶어.',
#  132: '이것은',
#  133: '어제',
#  134: '몇',
#  135: '전에',
#  136: '거짓말',
#  137: '이걸',
#  138: '다시',
#  139: '법을',
#  140: '사람이',
#  141: '미안해.',
#  142: '저',
#  143: '나를',
#  144: '둘',
#  145: '없었다.',
#  146: '갈',
#  147: '큰',
#  148: '보스턴에',
#  149: '이상',
#  150: '거기',
#  151: '학교에',
#  152: '메리를',
#  153: '가지',
#  154: '너한테',
#  155: '프랑스어',
#  156: '항상',
#  157: '안다.',
#  158: '여기에',
#  159: '뭔가',
#  160: '톰이랑',
#  161: '나한테',
#  162: '거의',
#  163: '뭘',
#  164: '세',
#  165: '절대',
#  166: '그를',
#  167: '제가',
#  168: '시간이',
#  169: '좋아해.',
#  170: '싶다.',
#  171: '거',
#  172: '어디',
#  173: '해야',
#  174: '거기에',
#  175: '몰랐어.',
#  176: '싶은',
#  177: '웃었어.',
#  178: '여기서',
#  179: '시간을',
#  180: '꽤',
#  181: '톰',
#  182: '본',
#  183: '거라고',
#  184: '사람들이',
#  185: '눈이',
#  186: '사람',
#  187: '위해',
#  188: '갔다.',
#  189: '진짜',
#  190: '보여.',
#  191: '일이',
#  192: '있나요?',
#  193: '모른다.',
#  194: '바로',
#  195: '봐.',
#  196: '저는',
#  197: '가고',
#  198: '좋다.',
#  199: '돈이',
#  200: '이제',
#  201: '필요하다.',
#  202: '모두가',
#  203: '좋아해?',
#  204: '매우',
#  205: '나에게',
#  206: '그런',
#  207: '없었어.',
#  208: '당신의',
#  209: '살고',
#  210: '가지고',
#  211: '매일',
#  212: '생각한다.',
#  213: '아무것도',
#  214: '정말로',
#  215: '열심히',
#  216: '와.',
#  217: '자신이',
#  218: '돼.',
#  219: '뭐야?',
#  220: '고양이를',
#  221: '좋아한다.',
#  222: '아니다.',
#  223: '말',
#  224: '같은',
#  225: '아는',
#  226: '했는데.',
#  227: '호주에',
#  228: '우리한테',
#  229: '줘.',
#  230: '그들이',
#  231: '비가',
#  232: '누군가',
#  233: '제',
#  234: '살',
#  235: '일을',
#  236: '될',
#  237: '언제',
#  238: '별로',
#  239: '필요가',
#  240: '배우고',
#  241: '동안',
#  242: '생각하지',
#  243: '함께',
#  244: '죽었어.',
#  245: '마세요.',
#  246: '빨리',
#  247: '말이',
#  248: '그냥',
#  249: '몰라.',
#  250: '안에',
#  251: '고양이는',
#  252: '있을까?',
#  253: '배웠어.',
#  254: '너희',
#  255: '훨씬',
#  256: '프랑스어로',
#  257: '당신이',
#  258: '나이에',
#  259: '비해',
#  260: '왔어.',
#  261: '말해.',
#  262: '이렇게',
#  263: '있어봐.',
#  264: '또',
#  265: '좋아.',
#  266: '갖고',
#  267: '있습니다.',
#  268: '프랑스어는',
#  269: '보인다.',
#  270: '모두들',
#  271: '있니?',
#  272: '곧',
#  273: '전혀',
#  274: '말했어.',
#  275: '있습니까?',
#  276: '좋아하지',
#  277: '어디서',
#  278: '좋겠어.',
#  279: '차를',
#  280: '생각해?',
#  281: '중',
#  282: '다른',
#  283: '알아.',
#  284: '사람을',
#  285: '키가',
#  286: '일은',
#  287: '기분이',
#  288: '보고',
#  289: '있어요.',
#  290: '메리의',
#  291: '언어를',
#  292: '도움이',
#  293: '이미',
#  294: '메리에게',
#  295: '조금',
#  296: '자주',
#  297: '너에게',
#  298: '먹고',
#  299: '이런',
#  300: '생각해.',
#  301: '우리의',
#  302: '프랑스',
#  303: '쓰고',
#  304: '싶어?',
#  305: '돈을',
#  306: '생각했어.',
#  307: '말았어야',
#  308: '탐은',
#  309: '다음',
#  310: '배우는',
#  311: '없는',
#  312: '알았어.',
#  313: '알아?',
#  314: '싫다.',
#  315: '나랑',
#  316: '수가',
#  317: '싫어.',
#  318: '같다.',
#  319: '우리에게',
#  320: '노래를',
#  321: '캐나다',
#  322: '어디로',
#  323: '그녀의',
#  324: '아마',
#  325: '무엇을',
#  326: '두',
#  327: '있지?',
#  328: '시작했다.',
#  329: '고양이',
#  330: '지난',
#  331: '한번',
#  332: '그에게',
#  333: '가는',
#  334: '혼자',
#  335: '입고',
#  336: '사람이야.',
#  337: '집을',
#  338: '없이',
#  339: '있다고',
#  340: '알았다.',
#  341: '있는지',
#  342: '번',
#  343: '서로',
#  344: '말하지',
#  345: '이렇게나',
#  346: '조용히',
#  347: '참',
#  348: '먹지',
#  349: '돼?',
#  350: '시간',
#  351: '너의',
#  352: '물',
#  353: '먹을',
#  354: '손을',
#  355: '이것을',
#  356: '아냐.',
#  357: '산다.',
#  358: '싶어',
#  359: '텐데.',
#  360: '문을',
#  361: '그치?',
#  362: '도와줄',
#  363: '보스턴에서',
#  364: '그녀가',
#  365: '되어',
#  366: '아침',
#  367: '가끔',
#  368: '좋겠다.',
#  369: '수는',
#  370: '보내고',
#  371: '가본',
#  372: '아름다운',
#  373: '들어.',
#  374: '거짓말을',
#  375: '뭐',
#  376: '수가!',
#  377: '당신',
#  378: '어때?',
#  379: '앉아',
#  380: '그거',
#  381: '그럴',
#  382: '사랑한다.',
#  383: '듣고',
#  384: '떠났다.',
#  385: '당신을',
#  386: '일하는',
#  387: '그것은',
#  388: '일하고',
#  389: '꿈을',
#  390: '물이',
#  391: '수도',
#  392: '톰도',
#  393: '물을',
#  394: '않아?',
#  395: '줄래?',
#  396: '쓴다.',
#  397: '봤어.',
#  398: '먹는',
#  399: '나도',
#  400: '뿐이야.',
#  401: '어디에',
#  402: '죽을',
#  403: '볼',
#  404: '너를',
#  405: '일찍',
#  406: '명',
#  407: '단지',
#  408: '자기가',
#  409: '한때',
#  410: '쓰는',
#  411: '싶었어.',
#  412: '오늘은',
#  413: '개를',
#  414: '못했다.',
#  415: '한번이라도',
#  416: '있다는',
#  417: '컴퓨터를',
#  418: '것에',
#  419: '중에',
#  420: '말하는',
#  421: '하는지',
#  422: '그다지',
#  423: '공부하는',
#  424: '나보다',
#  425: '데',
#  426: '파티에',
#  427: '않은데.',
#  428: '작은',
#  429: '줄은',
#  430: '문제는',
#  431: '저걸',
#  432: '혼자서',
#  433: '우리를',
#  434: '가자.',
#  435: '제발',
#  436: '누구',
#  437: '재미있다.',
#  438: '최선을',
#  439: '고양이가',
#  440: '머리가',
#  441: '늙었어.',
#  442: '계신가요?',
#  443: '도울',
#  444: '원한다.',
#  445: '찾고',
#  446: '조심해.',
#  447: '잘해.',
#  448: '쉽지',
#  449: '들어',
#  450: '된다.',
#  451: '오래된',
#  452: '침대에',
#  453: '공부하고',
#  454: '샀어.',
#  455: '얘기',
#  456: '아이들이',
#  457: '건가요?',
#  458: '사람의',
#  459: '돌아올',
#  460: '수영을',
#  461: '떠나야',
#  462: '못해.',
#  463: '이길',
#  464: '거라는',
#  465: '만난',
#  466: '월요일에',
#  467: '싶어하지',
#  468: '많다.',
#  469: '열쇠를',
#  470: '보았다.',
#  471: '것처럼',
#  472: '이야기를',
#  473: '들었다.',
#  474: '사실이야.',
#  475: '메리와',
#  476: '싶어해.',
#  477: '제일',
#  478: '뭔가가',
#  479: '딸은',
#  480: '있어서',
#  481: '개',
#  482: '실수를',
#  483: '갔으면',
#  484: '엄청',
#  485: '거지?',
#  486: '살아.',
#  487: '모자를',
#  488: '계란',
#  489: '메리',
#  490: '방',
#  491: '척',
#  492: '간다.',
#  493: '문제를',
#  494: '모르겠어.',
#  495: '대부분의',
#  496: '가',
#  497: '온',
#  498: '메리한테',
#  499: '오래',
#  500: '것이라고',
#  501: '보통',
#  502: '어려움을',
#  503: '일에',
#  504: '가.',
#  505: '저리',
#  506: '떠났어.',
#  507: '죄송합니다.',
#  508: '좋아요.',
#  509: '보세요.',
#  510: '가져.',
#  511: '와인',
#  512: '진실을',
#  513: '커.',
#  514: '괜찮은',
#  515: '감옥에',
#  516: '노래',
#  517: '아무',
#  518: '말도',
#  519: '차',
#  520: '나의',
#  521: '배를',
#  522: '새로운',
#  523: '싫어한다.',
#  524: '음악을',
#  525: '중독자야.',
#  526: '누구나',
#  527: '걸렸어.',
#  528: '걸렸다.',
#  529: '이름은',
#  530: '갔어.',
#  531: '필요해.',
#  532: '나에게는',
#  533: '여자',
#  534: '있어요?',
#  535: '점심',
#  536: '맥주를',
#  537: '사람이다.',
#  538: '해',
#  539: '피아노를',
#  540: '누구도',
#  541: '생각',
#  542: '싶어한다.',
#  543: '뭐가',
#  544: '여자가',
#  545: '영어를',
#  546: '올',
#  547: '줬어.',
#  548: '담배를',
#  549: '진짜로',
#  550: '노력했어.',
#  551: '방은',
#  552: '중이야.',
#  553: '꿈은',
#  554: '사실을',
#  555: '원숭이는',
#  556: '그곳에',
#  557: '더이상',
#  558: '유일한',
#  559: '살이',
#  560: '배울',
#  561: '테니스를',
#  562: '생각해',
#  563: '마리가',
#  564: '친구를',
#  565: '구성되어',
#  566: '어려워.',
#  567: '집에서',
#  568: '저녁을',
#  569: '지',
#  570: '있었으면',
#  571: '되고',
#  572: '작년에',
#  573: '저런',
#  574: '영어로',
#  575: '책은',
#  576: '방법을',
#  577: '같지',
#  578: '바란다.',
#  579: '여섯',
#  580: '누구야?',
#  581: '며칠',
#  582: '말라고',
#  583: '만약',
#  584: '새',
#  585: '할지',
#  586: '짓을',
#  587: '할아버지는',
#  588: '생일',
#  589: '없다고',
#  590: '버스가',
#  591: '가치가',
#  592: '결혼했어.',
#  593: '방법이',
#  594: '않는',
#  595: '같진',
#  596: '아니라',
#  597: '명의',
#  598: '시작해.',
#  599: '뭐라고',
#  600: '일해.',
#  601: '고마워.',
#  602: '그만해.',
#  603: '새가',
#  604: '개가',
#  605: '바라.',
#  606: '읽어.',
#  607: '울었어.',
#  608: '우릴',
#  609: '사실이야?',
#  610: '쳐.',
#  611: '춤을',
#  612: '부탁해.',
#  613: '남아',
#  614: '사람들',
#  615: '썼어.',
#  616: '물에',
#  617: '숨을',
#  618: '먹었다.',
#  619: '되나요?',
#  620: '톰.',
#  621: '그녀를',
#  622: '걱정',
#  623: '아니라고',
#  624: '않아요.',
#  625: '잠이',
#  626: '감기에',
#  627: '아름답다.',
#  628: '사실이',
#  629: '키우고',
#  630: '앉았다.',
#  631: '화가',
#  632: '도와',
#  633: '마음이',
#  634: '저를',
#  635: '방을',
#  636: '좋아해요?',
#  637: '남자를',
#  638: '왔다.',
#  639: '감기',
#  640: '형제가',
#  641: '인생은',
#  642: '사라졌어.',
#  643: '자고',
#  644: '친다.',
#  645: '은행',
#  646: '도와주지',
#  647: '때문에',
#  648: '좋아?',
#  649: '빌려',
#  650: '눈을',
#  651: '들었어.',
#  652: '세게',
#  653: '안경을',
#  654: '보냈어.',
#  655: '지하철로',
#  656: '갈게.',
#  657: '선생님이',
#  658: '시계를',
#  659: '전부야.',
#  660: '됐어.',
#  661: '지도',
#  662: '보였어.',
#  663: '인간이',
#  664: '조언을',
#  665: '걔는',
#  666: '학교를',
#  667: '전',
#  668: '태어났어.',
#  669: '어쩔',
#  670: '나이가',
#  671: '영어',
#  672: '지난주에',
#  673: '봤다.',
#  674: '만났다.',
#  675: '싶니?',
#  676: '있길',
#  677: '지난밤에',
#  678: '나중에',
#  679: '나와',
#  680: '몇몇',
#  681: '저게',
#  682: '약은',
#  683: '사실은',
#  684: '훌륭한',
#  685: '머리를',
#  686: '생일은',
#  687: '자신을',
#  688: '도움을',
#  689: '30분에',
#  690: '눈물로',
#  691: '가득했다.',
#  692: '시계는',
#  693: '생각을',
#  694: '하면',
#  695: '어느',
#  696: '마음에',
#  697: '아파트에서',
#  698: '치는',
#  699: '말하길',
#  700: '외로워',
#  701: '탔다.',
#  702: '동물이야.',
#  703: '된',
#  704: '합니다.',
#  705: '선생님이야.',
#  706: '위험한',
#  707: '가진',
#  708: '참을',
#  709: '운전하는',
#  710: '후에',
#  711: '말은',
#  712: '너랑',
#  713: '없습니다.',
#  714: '친구가',
#  715: '대한',
#  716: '너와',
#  717: '어떠한',
#  718: '뭔가를',
#  719: '줘야',
#  720: '마음을',
#  721: '거리를',
#  722: '하려고',
#  723: '소설을',
#  724: '정도로',
#  725: '시달리고',
#  726: '해?',
#  727: '처음',
#  728: '오스트레일리아에',
#  729: '모르겠다.',
#  730: '소프트웨어',
#  731: '있지',
#  732: '산',
#  733: '질문에',
#  734: '외로울',
#  735: '소식을',
#  736: '빼고',
#  737: '쓸',
#  738: '믿을',
#  739: '크리스마스',
#  740: '밤',
#  741: '오직',
#  742: '한다고',
#  743: '세상에',
#  744: '건지',
#  745: '내년에',
#  746: '경찰은',
#  747: '보스턴을',
#  748: '마지막',
#  749: '안다는',
#  750: '수영하러',
#  751: '말한',
#  752: '없어?',
#  753: '냉장고에',
#  754: '하기',
#  755: '어렸을',
#  756: '진정해.',
#  757: '잃어버렸다.',
#  758: '이겼어.',
#  759: '달린다.',
#  760: '마셔.',
#  761: '늦었어.',
#  762: '죽었다.',
#  763: '믿어.',
#  764: '그들을',
#  765: '내렸어.',
#  766: '당장',
#  767: '쳤어.',
#  768: '해봐.',
#  769: '하나',
#  770: '와!',
#  771: '마!',
#  772: '천천히',
#  773: '먹어.',
#  774: '가만히',
#  775: '집으로',
#  776: '인간이야.',
#  777: '기분',
#  778: '기억하고',
#  779: '남자',
#  780: '아프다.',
#  781: '공부해.',
#  782: '소리를',
#  783: '늦잠잤어.',
#  784: '빠져',
#  785: '아파요.',
#  786: '것입니다.',
#  787: '이해해.',
#  788: '끝냈어.',
#  789: '죽고',
#  790: '해줘.',
#  791: '비명을',
#  792: '자랐다.',
#  793: '울고',
#  794: '좋아합니다.',
#  795: '집이',
#  796: '나.',
#  797: '과학은',
#  798: '늦어서',
#  799: '싫어해.',
#  800: '귀신이',
#  801: '실제로',
#  802: '받았다.',
#  803: '사는',
#  804: '될까?',
#  805: '피가',
#  806: '운이',
#  807: '써.',
#  808: '너도',
#  809: '될까요?',
#  810: '생선',
#  811: '부르고',
#  812: '어째서',
#  813: '마리를',
#  814: '샀다.',
#  815: '누군지',
#  816: '떠난',
#  817: '일요일에',
#  818: '일한다.',
#  819: '근처에',
#  820: '아니었다.',
#  821: '책이',
#  822: '없어요.',
#  823: '어딨어?',
#  824: '전부',
#  825: '빠르게',
#  826: '일곱',
#  827: '일어났어.',
#  828: '자동차를',
#  829: '가르쳤어.',
#  830: '남자야.',
#  831: '쉽게',
#  832: '내버려',
#  833: '나갔다.',
#  834: '이것이',
#  835: '거미를',
#  836: '걸.',
#  837: '결코',
#  838: '맞다.',
#  839: '돈',
#  840: '낫다.',
#  841: '요리를',
#  842: '빨간색',
#  843: '있다면',
#  844: '좋을',
#  845: '더워졌다.',
#  846: '믿지',
#  847: '거미가',
#  848: '소심한',
#  849: '하나를',
#  850: '좋겠어?',
#  851: '다시는',
#  852: '연설은',
#  853: '있었어?',
#  854: '가족은',
#  855: '뻔',
#  856: '미안한데,',
#  857: '거기서',
#  858: '원숭이가',
#  859: '기다렸다.',
#  860: '여전히',
#  861: '개의',
#  862: '저희',
#  863: '밤에',
#  864: '과학이',
#  865: '기다리고',
#  866: '뛰어나다고',
#  867: '사고',
#  868: '그것에',
#  869: '열',
#  870: '궁금하게',
#  871: '그렇지',
#  872: '자신의',
#  873: '만났어.',
#  874: '종종',
#  875: '이상하게',
#  876: '확실히',
#  877: '마약',
#  878: '중독성',
#  879: '궁금하네.',
#  880: '싶습니다.',
#  881: '2시',
#  882: '사회적인',
#  883: '듣지',
#  884: '기회를',
#  885: '배워야',
#  886: '문제가',
#  887: '단어야.',
#  888: '커피를',
#  889: '들지',
#  890: '꿨어.',
#  891: '딸이',
#  892: '학교',
#  893: '없이는',
#  894: '밖에',
#  895: '시작했어.',
#  896: '피자',
#  897: '원하는',
#  898: '사과',
#  899: '않은',
#  900: '시간에',
#  901: '사진',
#  902: '하도록',
#  903: '저녁',
#  904: '이상한',
#  905: '기분이야.',
#  906: '좋지',
#  907: '곳에',
#  908: '더하기',
#  909: '말해',
#  910: '옷을',
#  911: '속에',
#  912: '중에서',
#  913: '공부해야',
#  914: '빵은',
#  915: '직접',
#  916: '있으신가요?',
#  917: '보지',
#  918: '걸릴',
#  919: '두는',
#  920: '되었어.',
#  921: '막',
#  922: '나쁜',
#  923: '작아.',
#  924: '어려.',
#  925: '달에',
#  926: '정확히',
#  927: '기타를',
#  928: '먹을래?',
#  929: '오지',
#  930: '당신과',
#  931: '관심',
#  932: '긴',
#  933: '숙제를',
#  934: '날씨가',
#  935: '읽고',
#  936: '알려',
#  937: '완전히',
#  938: '알게',
#  939: '때까지',
#  940: '간',
#  941: '읽지',
#  942: '대화할',
#  943: '누군가가',
#  944: '체스를',
#  945: '되지',
#  946: '빠질',
#  947: '많아.',
#  948: '진단받았어.',
#  949: '했다는',
#  950: '일주일에',
#  951: '쓰지',
#  952: '좋았을',
#  953: '누나는',
#  954: '주고',
#  955: '제대로',
#  956: '종류의',
#  957: '주었다.',
#  958: '말씀해',
#  959: '주시겠어요?',
#  960: '답할',
#  961: '과학',
#  962: '떠날',
#  963: '학교에서',
#  964: '만나고',
#  965: '돌아가셨다.',
#  966: '문장은',
#  967: '저한테',
#  968: '있다',
#  969: '해서',
#  970: '아침을',
#  971: '생각했다.',
#  972: '때가',
#  973: '번도',
#  974: '생각하는',
#  975: '생일을',
#  976: '직업을',
#  977: '가능성이',
#  978: '크리스마스를',
#  979: '만한',
#  980: '맞는',
#  981: '일주일',
#  982: '모른다고',
#  983: '호주에서',
#  984: '시험에',
#  985: '말할',
#  986: '오늘밤',
#  987: '일',
#  988: '부탁했다.',
#  989: '때는',
#  990: '우리랑',
#  991: '사실',
#  992: '딱히',
#  993: '것보다',
#  994: '방에',
#  995: '다들',
#  996: '다음에',
#  997: '원인은',
#  998: '혼자인',
#  999: '싶었다.',
#  1000: '상상도',
#  ...}

# %%
# 실제 사용 어휘 수(설정한 VOCAB_SIZE와 사전 크기 중 작은 값)
kor_num_words = min(VOCAB_SIZE, len(kor_tokenizer.word_index))

# 한국어 시퀀스들 중 가장 긴 문장의 토큰 길이
kor_max_len = max([len(seq) for seq in kor_inputs_seq])

print(kor_num_words, kor_max_len)
# Out:
# 8288 90

# %% [markdown]
# ### 패딩처리
# - 인코더 padding = 'pre'
# - 디코더 padding = 'post'

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences    # 시퀀스 길이를 맞추기 위한 패딩 함수

# 필수값: seq, maxlen=, padding= 영어는 인코더 / 한국어는 디코더
eng_inputs_padded = pad_sequences(eng_inputs_seq, maxlen=eng_max_len, padding='pre')     # 영어 입력은 최대길이 맞추고, 앞쪽에 0 패딩
kor_inputs_padded = pad_sequences(kor_inputs_seq, maxlen=kor_max_len, padding='post')    # 한국어 입력은 최대길이 맞추고, 뒤쪽에 0 패딩
kor_targets_padded = pad_sequences(kor_targets_seq, maxlen=kor_max_len, padding='post')  # 한국어 타겟도 최대길이 맞추고, 뒤쪽에 0 패딩

# %% [markdown]
# - 영어 (Encoder 입력) = pre 패딩 : 마지막 hidden state를 쓰는 경우가 많아서, 끝부분이 패딩(0)으로 끝나지 않게 실제 단어가 뒤로 오도록 한다.
# - 한국어 (Decoder 입력/타겟) = post 패딩 : 생성시에 왼쪽 -> 오른쪽으로 생성/Teaching Forcing 방식을 사용하여 앞에서부터 시점 정렬하는게 자연스럽고, 뒤에만 0이 붙어 loss 마스킹/처리가 쉽다.
#
# => 마스킹(mask_zero 등)을 사용한다면 pre/post가 크게 차이 나지 않는다.

# %% [markdown]
# ### 모델 생성
#
# `encoder + decoder(teach_forcing)` 구조의 모델 생성 및 학습
#
# #### Embedding Layer

# %%
with open('glove.6B.100d.txt', 'r', encoding='utf-8') as f:
    for i, vects in enumerate(f):    # 파일을 한 줄씩 읽으며 (인덱스 i, 라인 vects)로 순회
        print(vects)
        if i == 3:                   # 4번째 줄까지 출력 후
            break
# Out:
# the -0.038194 -0.24487 0.72812 -0.39961 0.083172 0.043953 -0.39141 0.3344 -0.57545 0.087459 0.28787 -0.06731 0.30906 -0.26384 -0.13231 -0.20757 0.33395 -0.33848 -0.31743 -0.48336 0.1464 -0.37304 0.34577 0.052041 0.44946 -0.46971 0.02628 -0.54155 -0.15518 -0.14107 -0.039722 0.28277 0.14393 0.23464 -0.31021 0.086173 0.20397 0.52624 0.17164 -0.082378 -0.71787 -0.41531 0.20335 -0.12763 0.41367 0.55187 0.57908 -0.33477 -0.36559 -0.54857 -0.062892 0.26584 0.30205 0.99775 -0.80481 -3.0243 0.01254 -0.36942 2.2167 0.72201 -0.24978 0.92136 0.034514 0.46745 1.1079 -0.19358 -0.074575 0.23353 -0.052062 -0.22044 0.057162 -0.15806 -0.30798 -0.41625 0.37972 0.15006 -0.53212 -0.2055 -1.2526 0.071624 0.70565 0.49744 -0.42063 0.26148 -1.538 -0.30223 -0.073438 -0.28312 0.37104 -0.25217 0.016215 -0.017099 -0.38984 0.87424 -0.72569 -0.51058 -0.52028 -0.1459 0.8278 0.27062
#
# , -0.10767 0.11053 0.59812 -0.54361 0.67396 0.10663 0.038867 0.35481 0.06351 -0.094189 0.15786 -0.81665 0.14172 0.21939 0.58505 -0.52158 0.22783 -0.16642 -0.68228 0.3587 0.42568 0.19021 0.91963 0.57555 0.46185 0.42363 -0.095399 -0.42749 -0.16567 -0.056842 -0.29595 0.26037 -0.26606 -0.070404 -0.27662 0.15821 0.69825 0.43081 0.27952 -0.45437 -0.33801 -0.58184 0.22364 -0.5778 -0.26862 -0.20425 0.56394 -0.58524 -0.14365 -0.64218 0.0054697 -0.35248 0.16162 1.1796 -0.47674 -2.7553 -0.1321 -0.047729 1.0655 1.1034 -0.2208 0.18669 0.13177 0.15117 0.7131 -0.35215 0.91348 0.61783 0.70992 0.23955 -0.14571 -0.37859 -0.045959 -0.47368 0.2385 0.20536 -0.18996 0.32507 -1.1112 -0.36341 0.98679 -0.084776 -0.54008 0.11726 -1.0194 -0.24424 0.12771 0.013884 0.080374 -0.35414 0.34951 -0.7226 0.37549 0.4441 -0.99059 0.61214 -0.35111 -0.83155 0.45293 0.082577
#
# . -0.33979 0.20941 0.46348 -0.64792 -0.38377 0.038034 0.17127 0.15978 0.46619 -0.019169 0.41479 -0.34349 0.26872 0.04464 0.42131 -0.41032 0.15459 0.022239 -0.64653 0.25256 0.043136 -0.19445 0.46516 0.45651 0.68588 0.091295 0.21875 -0.70351 0.16785 -0.35079 -0.12634 0.66384 -0.2582 0.036542 -0.13605 0.40253 0.14289 0.38132 -0.12283 -0.45886 -0.25282 -0.30432 -0.11215 -0.26182 -0.22482 -0.44554 0.2991 -0.85612 -0.14503 -0.49086 0.0082973 -0.17491 0.27524 1.4401 -0.21239 -2.8435 -0.27958 -0.45722 1.6386 0.78808 -0.55262 0.65 0.086426 0.39012 1.0632 -0.35379 0.48328 0.346 0.84174 0.098707 -0.24213 -0.27053 0.045287 -0.40147 0.11395 0.0062226 0.036673 0.018518 -1.0213 -0.20806 0.64072 -0.068763 -0.58635 0.33476 -1.1432 -0.1148 -0.25091 -0.45907 -0.096819 -0.17946 -0.063351 -0.67412 -0.068895 0.53604 -0.87773 0.31802 -0.39242 -0.23394 0.47298 -0.028803
#
# of -0.1529 -0.24279 0.89837 0.16996 0.53516 0.48784 -0.58826 -0.17982 -1.3581 0.42541 0.15377 0.24215 0.13474 0.41193 0.67043 -0.56418 0.42985 -0.012183 -0.11677 0.31781 0.054177 -0.054273 0.35516 -0.30241 0.31434 -0.33846 0.71715 -0.26855 -0.15837 -0.47467 0.051581 -0.33252 0.15003 -0.1299 -0.54617 -0.37843 0.64261 0.82187 -0.080006 0.078479 -0.96976 -0.57741 0.56491 -0.39873 -0.057099 0.19743 0.065706 -0.48092 -0.20125 -0.40834 0.39456 -0.02642 -0.11838 1.012 -0.53171 -2.7474 -0.042981 -0.74849 1.7574 0.59085 0.04885 0.78267 0.38497 0.42097 0.67882 0.10337 0.6328 -0.026595 0.58647 -0.44332 0.33057 -0.12022 -0.55645 0.073611 0.20915 0.43395 -0.012761 0.089874 -1.7991 0.084808 0.77112 0.63105 -0.90685 0.60326 -1.7515 0.18596 -0.50687 -0.70203 0.66578 -0.81304 0.18712 -0.018488 -0.26757 0.727 -0.59363 -0.34839 -0.56094 -0.591 1.0039 0.20664

# %% [markdown]
# 단어 값1 ~ 값100 형태로 나온다.

# %%
# 사전학습 임베딩(GloVe) 기반 Embedding Matrix 생성
import numpy as np

# 토크나이저의 단어 인덱스에 맞춰 사전학습 임베딩으로 embedding_matrix를 만드는 함수
def make_embedding_matrix(num_words, embedding_dim, tokenizer, file_path):
    embedding_matrix = np.zeros((num_words + 1, embedding_dim))  # (단어수+1, 임베딩차원) 0으로 초기화

    pretrained_embedding = {}

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            word, *vects = line.split()
            vects = np.array(vects, dtype=np.float32)   # 문자열 벡터값 -> float32 배열로 변환
            pretrained_embedding[word] = vects
    
    for word, index in tokenizer.word_index.items():    # 토크나이저의 (단어, 인덱스) 순회
        vects_ = pretrained_embedding.get(word)         # 해당 단어의 사전학습 벡터 조회 (없으면 None)
        if vects_ is not None:
            embedding_matrix[index] = vects_            # 해당 인덱스 위치에 벡터 삽입
    
    return embedding_matrix    # 사전학습 임베딩이 없는 단어는 0벡터로 나온다.

# %%
EMBEDDING_DIM = 100

# 영어 토크나이저 기준 임베딩 행렬 생성
en_embedding_matrix = make_embedding_matrix(
    eng_num_words,          # 사용할 어휘 수
    EMBEDDING_DIM,          # 임베딩 차원
    eng_tokenizer,          # 영어 토크나이저
    'glove.6B.100d.txt'     # GloVe 임베딩 파일 경로
)

en_embedding_matrix.shape
# Out:
# (3201, 100)

# %%
# 0번 인덱스를 <pad>로 두고, 이후 토큰들은 순서대로 리스트 생성
eng_word_index = ['<pad>'] + list(eng_tokenizer.index_word.values())

# %%
eng_word_index[0]
# Out:
# '<pad>'

# %%
import pandas as pd

pd.DataFrame(en_embedding_matrix, index=eng_word_index)
# Out:
#                   0         1        2         3         4         5   \
# <pad>       0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# <OOV>       0.000000  0.000000  0.00000  0.000000  0.000000  0.000000
# i          -0.046539  0.619660  0.56647 -0.465840 -1.189000  0.445990
# tom        -0.583880 -0.469400  0.16855 -1.670300 -0.116010  0.048738
# to         -0.189700  0.050024  0.19084 -0.049184 -0.089737  0.210060
# ...              ...       ...      ...       ...       ...       ...
# whom        0.341680  0.545720 -0.15683 -0.205450 -0.199470  0.389270
# intimately -0.416930  0.131300  0.50615  0.034870  0.255630  0.409070
# millions    0.622040  1.063600  0.13146 -0.203880  0.555570  0.443570
# inhabit    -0.927750  0.738860  0.69884  0.138580  0.020592  0.521490
# created     0.056525 -0.181480 -0.20936 -0.070561  0.950130  0.176020
#
#                   6         7         8        9   ...        90        91  \
# <pad>       0.000000  0.000000  0.000000  0.00000  ...  0.000000  0.000000
# <OOV>       0.000000  0.000000  0.000000  0.00000  ...  0.000000  0.000000
# i           0.066035  0.319100  0.146790 -0.22119  ... -0.323430 -0.431210
# tom        -0.342010 -0.376910 -0.953080 -0.88260  ...  0.264290  0.337860
# to         -0.549520  0.098377 -0.201350  0.34241  ... -0.131340  0.058617
# ...              ...       ...       ...      ...  ...       ...       ...
# whom       -0.017266 -0.244750  0.124760 -0.34392  ...  0.142210 -0.556420
# intimately  0.234080 -0.574340  0.293270  0.14061  ... -0.636420  0.066336
# millions   -0.524210  0.040587  0.470640 -0.53788  ... -0.063191 -0.111260
# inhabit    -0.541050  0.501790  0.206630 -0.51982  ...  0.491800 -0.235440
# created    -0.070017 -0.159640  0.047953 -0.38843  ...  0.090936 -0.250330
#
#                  92        93        94        95        96        97  \
# <pad>       0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# <OOV>       0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# i           0.41392  0.283740 -0.709310  0.150030 -0.215400 -0.376160
# tom         0.35791  0.549010  0.006725  0.281580  0.343730  0.137040
# to         -0.31869 -0.614190 -0.623930 -0.415480 -0.038175 -0.398040
# ...             ...       ...       ...       ...       ...       ...
# whom        0.45764 -0.243960 -1.146800  0.330140 -0.900430 -0.014213
# intimately -0.44926 -1.350100  0.381640 -0.051961 -0.425590 -0.667450
# millions    0.66609 -0.972050 -0.558910 -0.837910 -0.147160  0.862920
# inhabit     0.48243 -0.714400 -0.378190  0.271660 -1.243600 -0.288030
# created    -0.32441 -0.012409  0.268150  0.063334 -0.152150 -0.627600
#
#                   98        99
# <pad>       0.000000  0.000000
# <OOV>       0.000000  0.000000
# i          -0.032502  0.806200
# tom         0.089572 -0.542770
# to          0.476470 -0.159830
# ...              ...       ...
# whom        0.161420 -0.444830
# intimately  0.009747  0.061855
# millions    0.302910 -0.225640
# inhabit     0.065840  0.053163
# created     0.229480 -0.445260
#
# [3201 rows x 100 columns]

# %% [markdown]
# #### 인코더 모델

# %%
# Seq2Seq Encoder 모델 구성(사전학습 임베딩 + LSTM)
from tensorflow.keras import layers, models    # keras 레이어/모델 구성 모듈

LATENT_DIM = 512                               # LSTM 은닉 상태 차원(encoder state 크기)

encoder_inputs = layers.Input(shape=(eng_max_len,))    # (배치, eng_max_len) 형태의 단어 ID 입력
# 사전학습 임베딩 가중치로 Embedding layer 생성
en_embedding_layer = layers.Embedding(eng_num_words+1, EMBEDDING_DIM, weights=[en_embedding_matrix])
x = en_embedding_layer(encoder_inputs)    # (배치, 길이) -> (배치, 길이, EMBEDDING_DIM) 임베딩 변환
encoder_outputs, h, c = layers.LSTM(LATENT_DIM, return_state=True)(x)    # 마지막 출력값 + 최종 hidden(h) + cell(c) state 반환
encoder_states = [h, c]  # 디코더에 전달할 encoder state 묶기

encoder_model = models.Model(inputs=encoder_inputs, outputs=encoder_states)  # Encoder 입력 -> (h, c) 출력 모델 정의
encoder_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 101)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, 101, 100)       │       320,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ [(None, 512), (None,   │     1,255,424 │
# │                                 │ 512), (None, 512)]     │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,575,524 (6.01 MB)
#  Trainable params: 1,575,524 (6.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##### 디코더 모델 (Teacher-forcing)

# %%
# Seq2Seq Decoder 모델 구성 (Teacher Forcing 학습용)
decoder_inputs = layers.Input(shape=(kor_max_len,))    # (배치, kor_max_len) 형태의 디코더 (정답 시퀀스, <sos> 포함)
ko_embedding_layer = layers.Embedding(kor_num_words + 1, EMBEDDING_DIM)    # 한국어 단어 ID -> 임베딩 레이어
x = ko_embedding_layer(decoder_inputs)                 # (배치, 길이) -> (배치, 길이, EMBEDDING_DIM) 반환

decoder_lstm = layers.LSTM(LATENT_DIM, return_sequences=True, return_state=True)  # 시퀀스 전체 출력 + state(h, c) 반환 설정
x, h, c = decoder_lstm(x, initial_state=encoder_states)    # 인코더 state(h, c)를 초기 상태로 넣어 디코딩 수행

decoder_dense = layers.Dense(kor_num_words + 1, activation='softmax')  # 각 시점별 다음 단어 확률 분포 출력(어휘 크기)
decoder_outputs = decoder_dense(x)                     # (배치, 길이, kor_num_words+1) 소프트맥스 확률 생성

# 학습용 Seq2Seq 전체 모델 (Encoder + Decoder 결합)
decoder_teacher_forcing_model = models.Model(
    inputs = [encoder_inputs, decoder_inputs],  # 입력 : 영어 인코더 입력 + 한국어 디코더 입력
    outputs = decoder_outputs                   # 출력 : 한국어 다음 단어 분포(시점별)
)

decoder_teacher_forcing_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 101)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 90)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 101, 100)  │    320,100 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 90, 100)   │    828,900 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 512),     │  1,255,424 │ embedding[0][0]   │
# │                     │ (None, 512),      │            │                   │
# │                     │ (None, 512)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 90, 512), │  1,255,424 │ embedding_1[0][0… │
# │                     │ (None, 512),      │            │ lstm[0][1],       │
# │                     │ (None, 512)]      │            │ lstm[0][2]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 90, 8289)  │  4,252,257 │ lstm_1[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,912,105 (30.18 MB)
#  Trainable params: 7,912,105 (30.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - dense (Dense)       │ (None, 89, 10001)
#     - (batch, kor_max_len, kor_num_words + 1)

# %%
# 모델 시각화 목적 패키지
# %pip install pydot pydotplus graphviz
# Out:
# Requirement already satisfied: pydot in c:\users\playdata\nlp\nlp_venv\lib\site-packages (4.0.1)
# Requirement already satisfied: pydotplus in c:\users\playdata\nlp\nlp_venv\lib\site-packages (2.0.2)
# Requirement already satisfied: graphviz in c:\users\playdata\nlp\nlp_venv\lib\site-packages (0.21)
# Requirement already satisfied: pyparsing>=3.1.0 in c:\users\playdata\nlp\nlp_venv\lib\site-packages (from pydot) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.utils import plot_model    # keras 모델 구조를 이미지로 그려주는 유틸

plot_model(decoder_teacher_forcing_model, show_shapes=True)  # 레이어 연결도 + 각 레이어 출력 shape 표시
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
# Seq2Seq(Teacher Forcing) 모델 컴파일 및 학습
from tensorflow.keras.callbacks import CSVLogger    # 학습 로그를 CSV로 저장하는 콜백

csv_logger = CSVLogger("train_log.csv", append=True)  # 기존 파일이 있으면 이어서 기록

# 학습 설정 (손실, 옵티마이저, 평가지표)
decoder_teacher_forcing_model.compile(
    loss = 'sparse_categorical_crossentropy',  # 정답이 정수ID일때 쓰는 다중분류 손실
    optimizer = 'adam',
    metrics = ['accuracy']    # 토큰 단위 정확도 모니터링
)

# 모델 학습 진행
history = decoder_teacher_forcing_model.fit(
    [eng_inputs_padded, kor_inputs_padded],  # 입력 : 영어(인코더) + 한국어(<sos> 포함, 디코더 입력)
    kor_targets_padded,                      # 정답 : 한국어 타겟 (<eos> 포함) 시퀀스
    batch_size = 256,                        # 배치 크기
    epochs = 70,                             # 학습 반복 횟수
    validation_split = 0.2,                  # 검증 데이터 20% 사용
    callbacks=[csv_logger]                   # epoch마다 train_log.csv에 loss/acc 기록
)
# Out:
# Epoch 1/70
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 73s 4s/step - accuracy: 0.8970 - loss: 2.9009 - val_accuracy: 0.9185 - val_loss: 0.7150
# Epoch 2/70
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 75s 4s/step - accuracy: 0.9491 - loss: 0.3798 - val_accuracy: 0.9202 - val_loss: 0.6927
# Epoch 3/70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 14
#       7 decoder_teacher_forcing_model.compile(
#       8     loss = 'sparse_categorical_crossentropy',  # 정답이 정수ID일때 쓰는 다중분류 손실
#       9     optimizer = 'adam',
#      10     metrics = ['accuracy']    # 토큰 단위 정확도 모니터링
#      11 )
#      13 # 모델 학습 진행
# ---> 14 history = decoder_teacher_forcing_model.fit(
#      15     [eng_inputs_padded, kor_inputs_padded],  # 입력 : 영어(인코더) + 한국어(<sos> 포함, 디코더 입력)
#      16     kor_targets_padded,                      # 정답 : 한국어 타겟 (<eos> 포함) 시퀀스
#      17     batch_size = 256,                        # 배치 크기
#      18     epochs = 70,                             # 학습 반복 횟수
#      19     validation_split = 0.2,                  # 검증 데이터 20% 사용
#      20     callbacks=[csv_logger]                   # epoch마다 train_log.csv에 loss/acc 기록
#      21 )
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\Playdata\nlp\nlp_venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# 학습 로그(history) 시각화 (loss/accuracy 곡선) : 전체를 다 학습완료시 시각화
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot()  # hisotry(loss/acc/val_loss/val_acc)를 DataFrame으로 만들어 선 그래프 표시
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 4
#       1 # 학습 로그(history) 시각화 (loss/accuracy 곡선) : 전체를 다 학습완료시 시각화
#       2 import matplotlib.pyplot as plt
# ----> 4 pd.DataFrame(history.history).plot()  # hisotry(loss/acc/val_loss/val_acc)를 DataFrame으로 만들어 선 그래프 표시
#       5 plt.show()
#
# NameError: name 'history' is not defined

# %%
#  학습 로그(CSV 로그) 시각화 (loss/accuracy 곡선) : 중간에 끊었을 때 시각화
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("train_log.csv")
df = df.drop(columns=['epoch']).plot()
plt.show()

# %%
# Seq2Seq (Teacher Forcing) 모델 저장 (.keras 포맷)
decoder_teacher_forcing_model.save('decoder_teacher_forcing_model.keras')

# %%
# 저장된 Seq2Seq (Teacher Forcing) 모델 로드
from tensorflow.keras.models import load_model    # 저장된 keras 모델을 불러오는 함수
decoder_teacher_forcing_model = load_model('decoder_teacher_forcing_model.keras')

# %% [markdown]
# load_model을 사용해서 저장 당시의 모델 구조와 가중치가 복원되어 바로 predict()하거나 추가학습에 사용할 수 있습니다.

# %% [markdown]
# ### 모델 추론
#
# `encoder + decoder(inference)` 구조의 모델로 추론
#
# ##### 디코더 추론 모델

# %%
# Seq2Seq Decoder 추론용 모델 구성
decoder_hidden_state = layers.Input(shape=(LATENT_DIM,))    # 이전 시점 hidden state(h) 입력
decoder_cell_state = layers.Input(shape=(LATENT_DIM,))      # 이전 시점 cell state(c) 입력
decoder_states_inputs = [decoder_hidden_state, decoder_cell_state]  # (h, c) 상태 입력 묶음

decoder_single_input = layers.Input(shape=(1,))  # 추론시 1개 토큰(ID)만 입력 (한 스텝 디코딩)

x = ko_embedding_layer(decoder_single_input)     # (배치, 1) -> (배치, 1, EMBEDDING_DIM) 임베딩

x, h, c = decoder_lstm(x, initial_state=decoder_states_inputs)  # 입력 토큰 + 이전 상태(h, c)로 다음 상태 계산
decoder_states = [h, c]                          # 다음 스텝에 넘길 상태 (h, c) 저장

decoder_outputs_ = decoder_dense(x)              # (배치, 1, kor_num_words+1) 다음 단어 확률 분포 출록

# 추론용 디코더 모델 정의 (한 스텝)
decoder_inference_model = models.Model(
    inputs = [decoder_single_input] + decoder_states_inputs,  # 입력 : 현재 토큰 + 이전상태(h, c)
    outputs = [decoder_outputs_] + decoder_states            # 단어 분포 + 다음 상태(h, c)
)

decoder_inference_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 1, 100)    │    828,900 │ input_layer_4[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_2       │ (None, 512)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 512)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 1, 512),  │  1,255,424 │ embedding_1[1][0… │
# │                     │ (None, 512),      │            │ input_layer_2[0]… │
# │                     │ (None, 512)]      │            │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 8289)   │  4,252,257 │ lstm_1[1][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,336,581 (24.17 MB)
#  Trainable params: 6,336,581 (24.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
plot_model(decoder_inference_model, show_shapes=True)

# %% [markdown]
# ##### 추론 함수

# %%
# Seq2Seq 번역 함수 (Encoder-Decoder 추론 루프)
# 입력 영어 시퀀스를 인코더로 state 변환한 후, <sos>부터 시작해 한 단어씩 생성하는 번역 함수
def translate(input_seq):
    encoder_states_value = encoder_model.predict(input_seq)  # 인코더로부터 초기 상태 (h, c) 추출
    decoder_states_value = encoder_states_value              # 디코더 초기 상태를 인코더 상태로 설정

    sos_index = kor_tokenizer.word_index['<sos>']  # 시작 토큰(<sos>)의 ID
    eos_index = kor_tokenizer.word_index['<eos>']  # 종료 토큰(<eos>)의 ID

    target_seq = np.zeros((1, 1))    # 디코더 입력(현재 토큰) 자리 (배치1, 길이1)
    target_seq[0, 0] = sos_index     # 첫 입력 토큰은 <sos> 토큰

    output_sentence = []             # 생성된 단어(토큰)들을 담을 리스트

    for _ in range(kor_max_len):
        # (현재 토큰 + 이전 state)로 다음 토큰 분포와 state 예측
        output_tokens, h, c = decoder_inference_model.predict(
            [target_seq] + decoder_states_value
        )

        pred_proba = output_tokens[0, 0, :]  # (1, 1, V) -> (V, )로 확률 벡터 추출
        pred_index = np.argmax(pred_proba)   # 가장 확률이 큰 단어 ID 선택 (Greedy decoding)

        if pred_index == eos_index:          # eos가 나오면 문장 생성 종료
            break

        if pred_index > 0:                   # pad 인덱스가 아니면
            word = kor_tokenizer.index_word[pred_index]    # 예측 ID -> 단어로 역변환
            output_sentence.append(word)
        
        target_seq[0, 0] = pred_index    # 다음 스텝 입력 토큰을 이번 예측 토큰으로 갱신
        decoder_states_value = [h, c]    # 다음 스텝에 사용할 state(h, c) 갱신
    
    return " ".join(output_sentence)

# %% [markdown]
# ### 테스트

# %%
# 번역 입력 확인 및 1개 샘플 번역
print(eng_inputs[:1])     # 원본 영어 문장 첫 1개 확인

input_seq = eng_inputs_padded[:1]  # 첫 1개 영어 문장을 패딩된 시퀀스로 준비 (Batch 1)
translate(input_seq)
# Out:
# ['Go.']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# ''

# %%
# 랜덤 샘플 5개 번역 비교 출력
for _ in range(5):
    idx = np.random.choice(len(eng_inputs_padded))  # 전체 데이터 인덱스 중 하나를 무작위 선택
    input_seq = eng_inputs_padded[idx:idx+1]        # 선택된 1개 문장을 배치 형태(1개)로 준비
    output_sent = translate(input_seq)              # 추론 번역
    display("입력 영문 :", eng_inputs[idx])          # 원본 영어 문장
    display("학습된 국문 :", kor_inputs[idx])        # 학습용 한국어
    display("추론한 국문 :", output_sent)            # 모델이 생성한 한국어 번역
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# '입력 영문 :'
# 'Would you mind if I take a look?'
# '학습된 국문 :'
# '<sos> 내가 살펴봐도 괜찮아?'
# '추론한 국문 :'
# ''
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# '입력 영문 :'
# 'Please accept my apology.'
# '학습된 국문 :'
# '<sos> 제 사과를 받아 주세요.'
# '추론한 국문 :'
# ''
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# '입력 영문 :'
# 'I work.'
# '학습된 국문 :'
# '<sos> 나 일해.'
# '추론한 국문 :'
# ''
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# '입력 영문 :'
# "I don't care what you thought."
# '학습된 국문 :'
# '<sos> 네가 생각한 바에 난 개의치 않는다.'
# '추론한 국문 :'
# ''
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# '입력 영문 :'
# 'Do you want me to sing?'
# '학습된 국문 :'
# '<sos> 내가 노래 불러줬으면 좋겠어?'
# '추론한 국문 :'
# ''

# %%
# 영어 문장을 입력하면 한국어로 번역하는 래퍼함수
def translate_eng2kor(eng_text):
    input_seq = eng_tokenizer.texts_to_sequences(eng_text)    # 영어 문장(리스트)을 단어 ID 시퀀스로 변환
    input_seq = pad_sequences(input_seq, maxlen=eng_max_len)  # 인코더 입력 길이에 맞게 패딩 처리
    return translate(input_seq)    # 추론 함수로 번역 결과 반환

eng_texts = [
    "My hair is black.",
    "French is interesting.",
    "I like bus.",
    "Let\'s study",
    "I ate sandwich"
]

for eng_text in eng_texts:
    kor_text = translate_eng2kor([eng_text])  # 배치 형태로 넣기 위해 리스트로 감싸서 전달
    display(eng_text, kor_text)               # 원문 영어와 번역 결과를 함께 표시
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 'My hair is black.'
# ''
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 'French is interesting.'
# ''
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 'I like bus.'
# ''
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# "Let's study"
# ''
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 'I ate sandwich'
# ''
